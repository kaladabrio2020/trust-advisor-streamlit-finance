# %%
import investpy
# Out:
# c:\Users\mateu\Documents\Norton\Projetos GIT\trust-advisor-streamlit-finance\venv\Lib\site-packages\investpy\bonds.py:10: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
acoes_br = investpy.stocks.get_stocks(country="united states")
acoes_br[acoes_br['symbol'].str.contains('SP')]
# Out:
#             country                            name  \
# 69    united states                  Spartan Motors
# 301   united states                      S&P Global
# 364   united states                  Simon Property
# 467   united states                        SunPower
# 513   united states                    EW Scripps A
# 794   united states                  Biostar Pharma
# 925   united states                             CSP
# 991   united states                       DSP Group
# 1247  united states                        Innospec
# 1731  united states           Espey Mfg&Electronics
# 1735  united states      Franklin Street Properties
# 1819  united states                       InspireMD
# 1841  united states                       Perspecta
# 1846  united states                 US Physicalrapy
# 1897  united states              Spirit Aerosystems
# 1945  united states                 Spectrum Brands
# 2310  united states                       Insperity
# 2774  united states                   Sappi Ltd ADR
# 2800  united states           Spark New Zealand ADR
# 2803  united states             Starpharma Holdings
# 2960  united states          Singapore Exchange ADR
# 3076  united states        Superior Energy Services
# 3106  united states                          Splunk
# 3176  united states                         Univest
# 3293  united states                        Spectrum
# 3313  united states                     Esperion Th
# 3393  united states             Crispr Therapeutics
# 3455  united states                         Sapiens
# 3456  united states                     Support.com
# 3457  united states                    SPS Commerce
# 3466  united states                         Onespan
# 3478  united states                        XpresSpa
# 3499  united states                     SharpSpring
# 3667  united states                         Spherix
# 3668  united states                  SpartanNash Co
# 3671  united states                    SP Plus Corp
# 3794  united states                     Supercom Lt
# 3853  united states                      Sportsmans
# 3873  united states                Spark Energy Inc
# 3922  united states                      SPI Energy
# 4118  united states  Altisource Portfolio Solutions
# 4143  united states                     Aspen Group
# 4225  united states          South Plains Financial
# 4240  united states                   Spok Holdings
# 4461  united states                        SPX Corp
# 4523  united states              Chesapeake Lodging
#
#                                  full_name          isin currency symbol
# 69                      Spartan Motors Inc  US8468191007      USD   SPAR
# 301                         S&P Global Inc  US78409V1044      USD   SPGI
# 364               Simon Property Group Inc  US8288061091      USD    SPG
# 467                   SunPower Corporation  US8676524064      USD   SPWR
# 513               E. W. Scripps Co Class A  US8110544025      USD    SSP
# 794            Biostar Pharmaceuticals Inc  US0906783016      USD   BSPM
# 925                                CSP Inc  US1263891053      USD   CSPI
# 991                          DSP Group Inc  US23332B1061      USD   DSPG
# 1247                          Innospec Inc  US45768S1050      USD   IOSP
# 1731        Espey MFG and Electronics Corp  US2966501049      USD    ESP
# 1735       Franklin Street Properties Corp  US35471R1068      USD    FSP
# 1819                         InspireMD Inc  US45779A8532      USD   NSPR
# 1841                         Perspecta Inc  US7153471005      USD   PRSP
# 1846                   US Physicalrapy Inc  US90337L1089      USD   USPH
# 1897       Spirit Aerosystems Holdings Inc  US8485741099      USD    SPR
# 1945          Spectrum Brands Holdings Inc  US84790A1051      USD    SPB
# 2310                         Insperity Inc  US45778Q1076      USD    NSP
# 2774                         Sappi Ltd ADR  US8030692029      USD  SPPJY
# 2800             Spark New Zealand Ltd ADR  US84652A1025      USD  SPKKY
# 2803               Starpharma Holdings Ltd  US8555631022      USD  SPHRY
# 2960            Singapore Exchange Ltd ADR  US82929W1053      USD  SPXCY
# 3076          Superior Energy Services Inc  US8681571084      USD   SPNV
# 3106                            Splunk Inc  US8486371045      USD   SPLK
# 3176      Univest Corporation Pennsylvania  US9152711001      USD   UVSP
# 3293          Spectrum Pharmaceuticals Inc  US84763A1088      USD   SPPI
# 3313                           Esperion Th  US29664W1053      USD   ESPR
# 3393                Crispr Therapeutics AG  CH0334081137      USD   CRSP
# 3455  Sapiens International Corporation NV  KYG7T16G1039      USD   SPNS
# 3456                       Support.com Inc  US86858W2008      USD   SPRT
# 3457                      SPS Commerce Inc  US78463M1071      USD   SPSC
# 3466                           OneSpan Inc  US68287N1000      USD   OSPN
# 3478                    XpresSpa Group Inc  US98420U6047      USD   XSPA
# 3499                       SharpSpring Inc  US8200541048      USD   SHSP
# 3667                           Spherix Inc  US84842R5028      USD   SPEX
# 3668                        SpartanNash Co  US8472151005      USD   SPTN
# 3671                          SP Plus Corp  US78469C1036      USD     SP
# 3794                           Supercom Lt  IL0010830961      USD   SPCB
# 3853                            Sportsmans  US84920Y1064      USD   SPWH
# 3873                      Spark Energy Inc  US8465111032      USD   SPKE
# 3922                     SPI Energy Co Ltd  KYG8651P1101      USD    SPI
# 4118     Altisource Portfolio Solutions SA  LU0445408270      USD   ASPS
# 4143                       Aspen Group Inc  US04530L2034      USD   ASPU
# 4225            South Plains Financial Inc  US83946P1075      USD   SPFI
# 4240                     Spok Holdings Inc  US84863T1060      USD   SPOK
# 4461                              SPX Corp  US7846351044      USD   SPXC
# 4523              Chesapeake Lodging Trust  US1652401027      USD   CHSP

# %%
investpy.bonds.get_bonds(country="united states")['name'].unique().tolist()
# Out:
# ['U.S. 30Y',
#  'U.S. 10Y',
#  'U.S. 7Y',
#  'U.S. 5Y',
#  'U.S. 3Y',
#  'U.S. 3M',
#  'U.S. 1Y',
#  'U.S. 6M',
#  'U.S. 1M',
#  'U.S. 2Y']

# %%
import yfinance

def verificar_symbol(symbol: str) -> bool:
    dados = yfinance.download(symbol, period="1d", auto_adjust=True)
    return not dados.empty

print(verificar_symbol("AAPL"))    # True
print(verificar_symbol("XXXX.SA")) # False
print(verificar_symbol("A")) # False
# Out:
# [*********************100%***********************]  1 of 1 completed
# True
# HTTP Error 404:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['XXXX.SA']: YFPricesMissingError('possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")')
# False
# [*********************100%***********************]  1 of 1 completed
# True

# %%
import time 

'_'+ time.strftime("%Y_%m_%d_%H_%M_%S") + '_'
# Out:
# '_2025_08_21_22_18_15_'

# %%
verificar_symbol('BTC-USD')
# Out:
# [*********************100%***********************]  1 of 1 completed
# True

# %%
dados = yfinance.download("A", period="1d", auto_adjust=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ata = investpy.get_crypto_historical_data(crypto='bitcoin', from_date='01/01/2018', to_date='01/01/2019')
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ata = investpy.get_crypto_historical_data(crypto='bitcoin', from_date='01/01/2018', to_date='01/01/2019')
#
# File c:\Users\mateu\Documents\Norton\Projetos GIT\trust-advisor-streamlit-finance\venv\Lib\site-packages\investpy\crypto.py:598, in get_crypto_historical_data(crypto, from_date, to_date, as_json, order, interval)
#     595 req = requests.post(url, headers=head, data=params)
#     597 if req.status_code != 200:
# --> 598     raise ConnectionError(
#     599         "ERR#0015: error " + str(req.status_code) + ", try again later."
#     600     )
#     602 if not req.text:
#     603     continue
#
# ConnectionError: ERR#0015: error 403, try again later.
